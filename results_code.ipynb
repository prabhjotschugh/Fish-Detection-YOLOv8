# %%
from ultralytics import YOLO

# %%
model = YOLO("YOLOv8l_custom_trained_fine_tuned_model.pt")

# %%
results = model("Dataset/val/images/PH-8.png")
# Out:
# image 1/1 c:\Users\prabh\OneDrive\Desktop\Ocean Project Work\Fish Detection - YOLO\Dataset\val\images\PH-8.png: 448x640 1 Pecific herring, 3878.0ms
# Speed: 9.7ms preprocess, 3878.0ms inference, 4.5ms postprocess per image at shape (1, 3, 448, 640)

# %%
import cv2
import matplotlib.pyplot as plt

annotated_img = results[0].plot() 

plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis('off') 
plt.show()
